# %%
# AWS GLUE 
'''
 * What is use of Crawler?
 * What is difference b/w GLUE vs EMR ?
  
'''

#  Data Quality
'''
  * How data quality is managed?
'''

## Data Governance
'''
 * How data governance is managed ?

'''
