# %%
##### Databricks  ####
# What are the cluster type in Databricks 
# What is Unity Catalog ?
# What and all u have done to optimize the delta table?
# What is Z-order wit h detail with some example
# How aws swervice is integrated with Databricks ?

# %%
# PYSPARK
# IF we submit spark job what happens internally?
# what are the transformation have u done in pyspark ?

# Lets read a json file ( which is semi structured ) and it may contains nested structure data 
# and write it to delta table . what and all option u will be using it to read and write 


# If u have PB of data to process , How do you process it in pyspark and what optimziation u would do it to process it ?
# ASsume if it is historical load , then how are we going for it ?

# %%
# SQL 
# employee(eid,name, salary, location, )
# Fetch the employee whose salary is higher than average salary of thier respective location?

# %%
#Python
# Q) How to Drop duplicate element from list

# %%
# Pandas
# How to drop duplicate element from pandas 
# How to drop null values 
# How to Join pandas dataframe

# %%
# Numpy ?
